# %% [markdown]
# **This notebook aims to determine parameters of ensemble learning via cross validation.**
# --------------------
# ## 1) Model details:
# | Index| Model Flag    | Method |   Pretrain step | Finetune step | DCG on leaderboard |
# | --------| -------- | ------- | ------- | ------- | ------- |
# | 1| large_group2_wwm_from_unw4625K | M1 | 1700000 | 5130 | 11.96214 |
# | 2| large_group2_wwm_from_unw4625K | M1 | 1700000 | 4180 | NAN |
# | 3| base_group2_wwm | M2 | 2150000 | 5130 | ~11.32363 |
# | 4| large_group2_wwm_from_unw4625K | M1 | 590000 | 5130 | 11.94845 |
# | 5| large_group2_wwm_from_unw4625K | M1 | 1700000 | 4180 | NAN |
# | 6| large_group2_mt_pretrain | M3 | 1940000 | 5130 | NAN |
#
# ## 2) Method details
#
# | Method  | Model Layers |   Details |
# | -------- | ------- | ------- |
# | M1 | 24 | WWM & CTR prediction as pretraining tasks|
# | M2 | 12 | WWM & CTR prediction as pretraining tasks |
# | M3 | 24 | WWM & Multi-task CTR prediction as pretraining tasks|

# %%
valid_sparse_feat_addr = './features/sparse_features/annotation_data_0522.sparse.feat.undup'#.undup
test_sparse_feat_addr = './features/sparse_features/wsdm_test_2_all.sparse.feat.undup'

# %%
def get_bert_feat_addr(model_index, data_type):
    prefix = 'validation.' if data_type == 'valid' else ''
    addr = f'./features/bert_features/model{model_index}/{prefix}result.csv'
    return addr

# %%
import numpy as np
import pandas as pd
from tqdm.auto import tqdm
from pandas import DataFrame
from collections import defaultdict

# %%
def load_as_csv(data_addr, size, with_label=True):
    data = {'label':[], 'qid':[] }
    data.update({f'f{i+1}':[] for i in range(size)})
    for line in tqdm(open(data_addr)):
        splits = line.strip().split()
        label = splits[0]
        qid = splits[1].split(':')[1]
        data['label'].append(int(label))
        data['qid'].append(int(qid))
        for i,f in list(map(lambda s:s.split(':'), splits[2:])):
            data[f'f{i}'].append(float(f))

    return DataFrame(data)

# %%
def get_merge_feat_csv(sparse_feat_addr, *args):
    data = [[] for i in range(len(args))]
    for i,addr in enumerate(args):
        for line in open(addr):
            data[i].append(float(line.strip()))

    df = defaultdict(list)
    df.update({f'f{i+1}':[] for i in range(6)})
    for i,line in enumerate(open(sparse_feat_addr)):
        splits = line.strip().split()
        label = splits[0]
        qid = splits[1].split(':')[1]
        if '.' in qid:
            print(splits)
            break
        df['label'].append(int(label))
        df['qid'].append(int(qid))
        for j,f in list(map(lambda s:s.split(':'), splits[2:])):
            df[f'f{j}'].append(float(f))
        for idx in range(len(data)):
            df[f'f{6 + idx + 1}'].append(data[idx][i])
    return DataFrame(df)

# %%
feat_addrs = [get_bert_feat_addr(i, 'valid') for i in [1,2,3,4,6]]
all_data_df = get_merge_feat_csv(valid_sparse_feat_addr,*feat_addrs)

# %%
import lightgbm
def split_train_valid(df, train_ratio=0.8):
    qids = df['qid'].unique()
    np.random.seed(2023)
    np.random.shuffle(qids)
    split_point = int(len(qids) * train_ratio)
    train_qids = set(qids[:split_point])
    valid_qids = set(qids[split_point:])
    
    train_df = df.loc[df['qid'].isin(train_qids)]
    valid_df = df.loc[df['qid'].isin(valid_qids)]
    return train_df,valid_df

def prepare_data(df):
    qids_group = df.groupby("qid")["qid"].count().to_numpy()
    X_train = df.drop(["qid", "label"], axis = 1)
    # Relevance label for train
    y_train = df['label'].astype(int)
    return X_train, y_train, qids_group

def select_train(df, train_ratio):
    ranker = lightgbm.LGBMRanker(
                    objective="lambdarank",
                    boosting_type = "gbdt",
                    n_estimators = 500,
                    importance_type = "gain",
                    metric= "ndcg",
                    num_leaves = 30,
                    learning_rate = 0.05,
                    max_depth = -1,)#If random_state is None, default seeds in C++ code are used.
    
    train_df,valid_df = split_train_valid(df, train_ratio)
    x_train,y_train,qid_group_train = prepare_data(train_df)
    x_test,y_test,qid_group_test = prepare_data(valid_df)
    ranker.fit(
          X=x_train,
          y=y_train,
          group=qid_group_train,
          eval_set=[(x_test, y_test),],
          eval_group=[qid_group_test, ],
          eval_at=[10])
    return ranker

# %%
train_df,valid_df = split_train_valid(all_data_df, train_ratio=0.8)

# %%
sranker = select_train(valid_df, 0.8)
#seed = 123
#epoch=500, leave=30, lr=0.05, 0.821512
#epoch=100, leave=30, lr=0.05, 0.821748
#epoch=100, leave=10, lr=0.05, 0.826392 ***
#epoch=100, leave=20, lr=0.05, 0.826137
#epoch=100, leave=10, lr=0.01, 0.825981

#seed = 2023
#epoch=500, leave=30, lr=0.05, 0.811326
#epoch=100, leave=30, lr=0.05, 0.817943
#epoch=100, leave=10, lr=0.05, 0.820679 ***
#epoch=100, leave=20, lr=0.05, 0.814458
#epoch=100, leave=10, lr=0.01, 0.816119
# Out:
# [1]	valid_0's ndcg@10: 0.79007
# [2]	valid_0's ndcg@10: 0.807151
# [3]	valid_0's ndcg@10: 0.805741
# [4]	valid_0's ndcg@10: 0.807598
# [5]	valid_0's ndcg@10: 0.808061
# [6]	valid_0's ndcg@10: 0.809606
# [7]	valid_0's ndcg@10: 0.808922
# [8]	valid_0's ndcg@10: 0.806076
# [9]	valid_0's ndcg@10: 0.806653
# [10]	valid_0's ndcg@10: 0.810297
# [11]	valid_0's ndcg@10: 0.809622
# [12]	valid_0's ndcg@10: 0.811707
# [13]	valid_0's ndcg@10: 0.813054
# [14]	valid_0's ndcg@10: 0.812945
# [15]	valid_0's ndcg@10: 0.815191
# [16]	valid_0's ndcg@10: 0.812636
# [17]	valid_0's ndcg@10: 0.813891
# [18]	valid_0's ndcg@10: 0.815498
# [19]	valid_0's ndcg@10: 0.815169
# [20]	valid_0's ndcg@10: 0.816988
# [21]	valid_0's ndcg@10: 0.817538
# [22]	valid_0's ndcg@10: 0.815596
# [23]	valid_0's ndcg@10: 0.81484
# [24]	valid_0's ndcg@10: 0.815743
# [25]	valid_0's ndcg@10: 0.815495
# [26]	valid_0's ndcg@10: 0.816304
# [27]	valid_0's ndcg@10: 0.814687
# [28]	valid_0's ndcg@10: 0.8168
# [29]	valid_0's ndcg@10: 0.816603
# [30]	valid_0's ndcg@10: 0.816264
# [31]	valid_0's ndcg@10: 0.816165
# [32]	valid_0's ndcg@10: 0.81545
# [33]	valid_0's ndcg@10: 0.816455
# [34]	valid_0's ndcg@10: 0.816177
# [35]	valid_0's ndcg@10: 0.815981
# [36]	valid_0's ndcg@10: 0.817097
# [37]	valid_0's ndcg@10: 0.816744
# [38]	valid_0's ndcg@10: 0.81584
# [39]	valid_0's ndcg@10: 0.815544
# [40]	valid_0's ndcg@10: 0.814932
# [41]	valid_0's ndcg@10: 0.814942
# [42]	valid_0's ndcg@10: 0.815321
# [43]	valid_0's ndcg@10: 0.815763
# [44]	valid_0's ndcg@10: 0.815763
# [45]	valid_0's ndcg@10: 0.815717
# [46]	valid_0's ndcg@10: 0.815666
# [47]	valid_0's ndcg@10: 0.814099
# [48]	valid_0's ndcg@10: 0.814829
# [49]	valid_0's ndcg@10: 0.814499
# [50]	valid_0's ndcg@10: 0.815431
# [51]	valid_0's ndcg@10: 0.815397
# [52]	valid_0's ndcg@10: 0.815598
# [53]	valid_0's ndcg@10: 0.816197
# [54]	valid_0's ndcg@10: 0.816496
# [55]	valid_0's ndcg@10: 0.815829
# [56]	valid_0's ndcg@10: 0.815416
# [57]	valid_0's ndcg@10: 0.815194
# [58]	valid_0's ndcg@10: 0.815343
# [59]	valid_0's ndcg@10: 0.815533
# [60]	valid_0's ndcg@10: 0.815565
# [61]	valid_0's ndcg@10: 0.815444
# [62]	valid_0's ndcg@10: 0.814578
# [63]	valid_0's ndcg@10: 0.815557
# [64]	valid_0's ndcg@10: 0.815767
# [65]	valid_0's ndcg@10: 0.816814
# [66]	valid_0's ndcg@10: 0.817071
# [67]	valid_0's ndcg@10: 0.816916
# [68]	valid_0's ndcg@10: 0.817249
# [69]	valid_0's ndcg@10: 0.817024
# [70]	valid_0's ndcg@10: 0.817582
# [71]	valid_0's ndcg@10: 0.817625
# [72]	valid_0's ndcg@10: 0.816973
# [73]	valid_0's ndcg@10: 0.817566
# [74]	valid_0's ndcg@10: 0.818127
# [75]	valid_0's ndcg@10: 0.817534
# [76]	valid_0's ndcg@10: 0.817304
# [77]	valid_0's ndcg@10: 0.81728
# [78]	valid_0's ndcg@10: 0.818306
# [79]	valid_0's ndcg@10: 0.81773
# [80]	valid_0's ndcg@10: 0.818438
# [81]	valid_0's ndcg@10: 0.818522
# [82]	valid_0's ndcg@10: 0.818768
# [83]	valid_0's ndcg@10: 0.819274
# [84]	valid_0's ndcg@10: 0.81891
# [85]	valid_0's ndcg@10: 0.818588
# [86]	valid_0's ndcg@10: 0.818801
# [87]	valid_0's ndcg@10: 0.817922
# [88]	valid_0's ndcg@10: 0.817744
# [89]	valid_0's ndcg@10: 0.817596
# [90]	valid_0's ndcg@10: 0.81723
# [91]	valid_0's ndcg@10: 0.817078
# [92]	valid_0's ndcg@10: 0.816978
# [93]	valid_0's ndcg@10: 0.816889
# [94]	valid_0's ndcg@10: 0.817397
# [95]	valid_0's ndcg@10: 0.817493
# [96]	valid_0's ndcg@10: 0.817957
# [97]	valid_0's ndcg@10: 0.818986
# [98]	valid_0's ndcg@10: 0.817723
# [99]	valid_0's ndcg@10: 0.817893
# [100]	valid_0's ndcg@10: 0.817943
# [101]	valid_0's ndcg@10: 0.818065
# [102]	valid_0's ndcg@10: 0.817749
# [103]	valid_0's ndcg@10: 0.817344
# [104]	valid_0's ndcg@10: 0.817454
# [105]	valid_0's ndcg@10: 0.816997
# [106]	valid_0's ndcg@10: 0.816772
# [107]	valid_0's ndcg@10: 0.817209
# [108]	valid_0's ndcg@10: 0.817103
# [109]	valid_0's ndcg@10: 0.817361
# [110]	valid_0's ndcg@10: 0.817703
# [111]	valid_0's ndcg@10: 0.816901
# [112]	valid_0's ndcg@10: 0.816986
# [113]	valid_0's ndcg@10: 0.816495
# [114]	valid_0's ndcg@10: 0.81774
# [115]	valid_0's ndcg@10: 0.817365
# [116]	valid_0's ndcg@10: 0.816903
# [117]	valid_0's ndcg@10: 0.817043
# [118]	valid_0's ndcg@10: 0.817413
# [119]	valid_0's ndcg@10: 0.817915
# [120]	valid_0's ndcg@10: 0.817842
# [121]	valid_0's ndcg@10: 0.818522
# [122]	valid_0's ndcg@10: 0.818402
# [123]	valid_0's ndcg@10: 0.818305
# [124]	valid_0's ndcg@10: 0.818826
# [125]	valid_0's ndcg@10: 0.818611
# [126]	valid_0's ndcg@10: 0.818566
# [127]	valid_0's ndcg@10: 0.818718
# [128]	valid_0's ndcg@10: 0.818312
# [129]	valid_0's ndcg@10: 0.818376
# [130]	valid_0's ndcg@10: 0.818309
# [131]	valid_0's ndcg@10: 0.818075
# [132]	valid_0's ndcg@10: 0.818142
# [133]	valid_0's ndcg@10: 0.819163
# [134]	valid_0's ndcg@10: 0.819286
# [135]	valid_0's ndcg@10: 0.819171
# [136]	valid_0's ndcg@10: 0.819362
# [137]	valid_0's ndcg@10: 0.818882
# [138]	valid_0's ndcg@10: 0.818813
# [139]	valid_0's ndcg@10: 0.818827
# [140]	valid_0's ndcg@10: 0.818602
# [141]	valid_0's ndcg@10: 0.818129
# [142]	valid_0's ndcg@10: 0.817847
# [143]	valid_0's ndcg@10: 0.818393
# [144]	valid_0's ndcg@10: 0.8191
# [145]	valid_0's ndcg@10: 0.818756
# [146]	valid_0's ndcg@10: 0.817983
# [147]	valid_0's ndcg@10: 0.817794
# [148]	valid_0's ndcg@10: 0.817552
# [149]	valid_0's ndcg@10: 0.817544
# [150]	valid_0's ndcg@10: 0.818438
# [151]	valid_0's ndcg@10: 0.81752
# [152]	valid_0's ndcg@10: 0.817611
# [153]	valid_0's ndcg@10: 0.817355
# [154]	valid_0's ndcg@10: 0.816592
# [155]	valid_0's ndcg@10: 0.817368
# [156]	valid_0's ndcg@10: 0.81725
# [157]	valid_0's ndcg@10: 0.817595
# [158]	valid_0's ndcg@10: 0.817362
# [159]	valid_0's ndcg@10: 0.81774
# [160]	valid_0's ndcg@10: 0.817086
# [161]	valid_0's ndcg@10: 0.816533
# [162]	valid_0's ndcg@10: 0.81496
# [163]	valid_0's ndcg@10: 0.81552
# [164]	valid_0's ndcg@10: 0.815795
# [165]	valid_0's ndcg@10: 0.814891
# [166]	valid_0's ndcg@10: 0.814556
# [167]	valid_0's ndcg@10: 0.814752
# [168]	valid_0's ndcg@10: 0.815721
# [169]	valid_0's ndcg@10: 0.815713
# [170]	valid_0's ndcg@10: 0.815619
# [171]	valid_0's ndcg@10: 0.81525
# [172]	valid_0's ndcg@10: 0.814725
# [173]	valid_0's ndcg@10: 0.814654
# [174]	valid_0's ndcg@10: 0.81533
# [175]	valid_0's ndcg@10: 0.814851
# [176]	valid_0's ndcg@10: 0.814665
# [177]	valid_0's ndcg@10: 0.814319
# [178]	valid_0's ndcg@10: 0.814153
# [179]	valid_0's ndcg@10: 0.813622
# [180]	valid_0's ndcg@10: 0.814094
# [181]	valid_0's ndcg@10: 0.813994
# [182]	valid_0's ndcg@10: 0.813882
# [183]	valid_0's ndcg@10: 0.813233
# [184]	valid_0's ndcg@10: 0.815248
# [185]	valid_0's ndcg@10: 0.815058
# [186]	valid_0's ndcg@10: 0.814401
# [187]	valid_0's ndcg@10: 0.814682
# [188]	valid_0's ndcg@10: 0.814823
# [189]	valid_0's ndcg@10: 0.815027
# [190]	valid_0's ndcg@10: 0.814686
# [191]	valid_0's ndcg@10: 0.814581
# [192]	valid_0's ndcg@10: 0.814234
# [193]	valid_0's ndcg@10: 0.814087
# [194]	valid_0's ndcg@10: 0.814445
# [195]	valid_0's ndcg@10: 0.814519
# [196]	valid_0's ndcg@10: 0.814511
# [197]	valid_0's ndcg@10: 0.814449
# [198]	valid_0's ndcg@10: 0.814471
# [199]	valid_0's ndcg@10: 0.814544
# [200]	valid_0's ndcg@10: 0.814811
# [201]	valid_0's ndcg@10: 0.81448
# [202]	valid_0's ndcg@10: 0.81452
# [203]	valid_0's ndcg@10: 0.814564
# [204]	valid_0's ndcg@10: 0.814608
# [205]	valid_0's ndcg@10: 0.814515
# [206]	valid_0's ndcg@10: 0.814235
# [207]	valid_0's ndcg@10: 0.814458
# [208]	valid_0's ndcg@10: 0.814705
# [209]	valid_0's ndcg@10: 0.814704
# [210]	valid_0's ndcg@10: 0.81459
# [211]	valid_0's ndcg@10: 0.814546
# [212]	valid_0's ndcg@10: 0.814994
# [213]	valid_0's ndcg@10: 0.814951
# [214]	valid_0's ndcg@10: 0.814707
# [215]	valid_0's ndcg@10: 0.814761
# [216]	valid_0's ndcg@10: 0.814577
# [217]	valid_0's ndcg@10: 0.814674
# [218]	valid_0's ndcg@10: 0.814719
# [219]	valid_0's ndcg@10: 0.814547
# [220]	valid_0's ndcg@10: 0.814599
# [221]	valid_0's ndcg@10: 0.814638
# [222]	valid_0's ndcg@10: 0.814561
# [223]	valid_0's ndcg@10: 0.814666
# [224]	valid_0's ndcg@10: 0.814897
# [225]	valid_0's ndcg@10: 0.81521
# [226]	valid_0's ndcg@10: 0.815275
# [227]	valid_0's ndcg@10: 0.815416
# [228]	valid_0's ndcg@10: 0.816183
# [229]	valid_0's ndcg@10: 0.816509
# [230]	valid_0's ndcg@10: 0.816758
# [231]	valid_0's ndcg@10: 0.816671
# [232]	valid_0's ndcg@10: 0.816198
# [233]	valid_0's ndcg@10: 0.81616
# [234]	valid_0's ndcg@10: 0.816157
# [235]	valid_0's ndcg@10: 0.816306
# [236]	valid_0's ndcg@10: 0.815508
# [237]	valid_0's ndcg@10: 0.815754
# [238]	valid_0's ndcg@10: 0.815932
# [239]	valid_0's ndcg@10: 0.815866
# [240]	valid_0's ndcg@10: 0.816228
# [241]	valid_0's ndcg@10: 0.815823
# [242]	valid_0's ndcg@10: 0.815884
# [243]	valid_0's ndcg@10: 0.815381
# [244]	valid_0's ndcg@10: 0.815051
# [245]	valid_0's ndcg@10: 0.814613
# [246]	valid_0's ndcg@10: 0.815557
# [247]	valid_0's ndcg@10: 0.815197
# [248]	valid_0's ndcg@10: 0.814683
# [249]	valid_0's ndcg@10: 0.814833
# [250]	valid_0's ndcg@10: 0.813984
# [251]	valid_0's ndcg@10: 0.81423
# [252]	valid_0's ndcg@10: 0.814044
# [253]	valid_0's ndcg@10: 0.814368
# [254]	valid_0's ndcg@10: 0.814664
# [255]	valid_0's ndcg@10: 0.814493
# [256]	valid_0's ndcg@10: 0.81426
# [257]	valid_0's ndcg@10: 0.814487
# [258]	valid_0's ndcg@10: 0.814639
# [259]	valid_0's ndcg@10: 0.814634
# [260]	valid_0's ndcg@10: 0.814622
# [261]	valid_0's ndcg@10: 0.814415
# [262]	valid_0's ndcg@10: 0.814534
# [263]	valid_0's ndcg@10: 0.81457
# [264]	valid_0's ndcg@10: 0.814312
# [265]	valid_0's ndcg@10: 0.814499
# [266]	valid_0's ndcg@10: 0.814651
# [267]	valid_0's ndcg@10: 0.814533
# [268]	valid_0's ndcg@10: 0.814555
# [269]	valid_0's ndcg@10: 0.815205
# [270]	valid_0's ndcg@10: 0.815253
# [271]	valid_0's ndcg@10: 0.815304
# [272]	valid_0's ndcg@10: 0.814777
# [273]	valid_0's ndcg@10: 0.814849
# [274]	valid_0's ndcg@10: 0.814586
# [275]	valid_0's ndcg@10: 0.813761
# [276]	valid_0's ndcg@10: 0.813841
# [277]	valid_0's ndcg@10: 0.813806
# [278]	valid_0's ndcg@10: 0.81387
# [279]	valid_0's ndcg@10: 0.813567
# [280]	valid_0's ndcg@10: 0.81387
# [281]	valid_0's ndcg@10: 0.813867
# [282]	valid_0's ndcg@10: 0.813783
# [283]	valid_0's ndcg@10: 0.813472
# [284]	valid_0's ndcg@10: 0.812814
# [285]	valid_0's ndcg@10: 0.8132
# [286]	valid_0's ndcg@10: 0.812907
# [287]	valid_0's ndcg@10: 0.813143
# [288]	valid_0's ndcg@10: 0.81267
# [289]	valid_0's ndcg@10: 0.813138
# [290]	valid_0's ndcg@10: 0.812954
# [291]	valid_0's ndcg@10: 0.813081
# [292]	valid_0's ndcg@10: 0.81308
# [293]	valid_0's ndcg@10: 0.813112
# [294]	valid_0's ndcg@10: 0.812903
# [295]	valid_0's ndcg@10: 0.812732
# [296]	valid_0's ndcg@10: 0.812674
# [297]	valid_0's ndcg@10: 0.812888
# [298]	valid_0's ndcg@10: 0.813244
# [299]	valid_0's ndcg@10: 0.812657
# [300]	valid_0's ndcg@10: 0.812418
# [301]	valid_0's ndcg@10: 0.813206
# [302]	valid_0's ndcg@10: 0.812949
# [303]	valid_0's ndcg@10: 0.812825
# [304]	valid_0's ndcg@10: 0.812909
# [305]	valid_0's ndcg@10: 0.812909
# [306]	valid_0's ndcg@10: 0.812909
# [307]	valid_0's ndcg@10: 0.81259
# [308]	valid_0's ndcg@10: 0.81288
# [309]	valid_0's ndcg@10: 0.812654
# [310]	valid_0's ndcg@10: 0.813276
# [311]	valid_0's ndcg@10: 0.81326
# [312]	valid_0's ndcg@10: 0.813178
# [313]	valid_0's ndcg@10: 0.813088
# [314]	valid_0's ndcg@10: 0.812483
# [315]	valid_0's ndcg@10: 0.812668
# [316]	valid_0's ndcg@10: 0.812985
# [317]	valid_0's ndcg@10: 0.812967
# [318]	valid_0's ndcg@10: 0.812872
# [319]	valid_0's ndcg@10: 0.813051
# [320]	valid_0's ndcg@10: 0.812918
# [321]	valid_0's ndcg@10: 0.81302
# [322]	valid_0's ndcg@10: 0.813077
# [323]	valid_0's ndcg@10: 0.812817
# [324]	valid_0's ndcg@10: 0.812662
# [325]	valid_0's ndcg@10: 0.812644
# [326]	valid_0's ndcg@10: 0.812358
# [327]	valid_0's ndcg@10: 0.812545
# [328]	valid_0's ndcg@10: 0.812868
# [329]	valid_0's ndcg@10: 0.812753
# [330]	valid_0's ndcg@10: 0.812806
# [331]	valid_0's ndcg@10: 0.812836
# [332]	valid_0's ndcg@10: 0.812862
# [333]	valid_0's ndcg@10: 0.812907
# [334]	valid_0's ndcg@10: 0.81293
# [335]	valid_0's ndcg@10: 0.812465
# [336]	valid_0's ndcg@10: 0.812465
# [337]	valid_0's ndcg@10: 0.812465
# [338]	valid_0's ndcg@10: 0.812648
# [339]	valid_0's ndcg@10: 0.812615
# [340]	valid_0's ndcg@10: 0.812832
# [341]	valid_0's ndcg@10: 0.812744
# [342]	valid_0's ndcg@10: 0.812804
# [343]	valid_0's ndcg@10: 0.813017
# [344]	valid_0's ndcg@10: 0.812981
# [345]	valid_0's ndcg@10: 0.812594
# [346]	valid_0's ndcg@10: 0.812526
# [347]	valid_0's ndcg@10: 0.812558
# [348]	valid_0's ndcg@10: 0.812641
# [349]	valid_0's ndcg@10: 0.812769
# [350]	valid_0's ndcg@10: 0.812764
# [351]	valid_0's ndcg@10: 0.812764
# [352]	valid_0's ndcg@10: 0.812791
# [353]	valid_0's ndcg@10: 0.812791
# [354]	valid_0's ndcg@10: 0.812772
# [355]	valid_0's ndcg@10: 0.813532
# [356]	valid_0's ndcg@10: 0.813648
# [357]	valid_0's ndcg@10: 0.81357
# [358]	valid_0's ndcg@10: 0.813572
# [359]	valid_0's ndcg@10: 0.813573
# [360]	valid_0's ndcg@10: 0.812978
# [361]	valid_0's ndcg@10: 0.813071
# [362]	valid_0's ndcg@10: 0.813025
# [363]	valid_0's ndcg@10: 0.812309
# [364]	valid_0's ndcg@10: 0.812082
# [365]	valid_0's ndcg@10: 0.811935
# [366]	valid_0's ndcg@10: 0.811992
# [367]	valid_0's ndcg@10: 0.811823
# [368]	valid_0's ndcg@10: 0.811921
# [369]	valid_0's ndcg@10: 0.812206
# [370]	valid_0's ndcg@10: 0.812416
# [371]	valid_0's ndcg@10: 0.812392
# [372]	valid_0's ndcg@10: 0.81236
# [373]	valid_0's ndcg@10: 0.812858
# [374]	valid_0's ndcg@10: 0.812816
# [375]	valid_0's ndcg@10: 0.81241
# [376]	valid_0's ndcg@10: 0.812401
# [377]	valid_0's ndcg@10: 0.812422
# [378]	valid_0's ndcg@10: 0.812422
# [379]	valid_0's ndcg@10: 0.812072
# [380]	valid_0's ndcg@10: 0.812072
# [381]	valid_0's ndcg@10: 0.812008
# [382]	valid_0's ndcg@10: 0.812252
# [383]	valid_0's ndcg@10: 0.812556
# [384]	valid_0's ndcg@10: 0.812378
# [385]	valid_0's ndcg@10: 0.812118
# [386]	valid_0's ndcg@10: 0.812
# [387]	valid_0's ndcg@10: 0.811705
# [388]	valid_0's ndcg@10: 0.811754
# [389]	valid_0's ndcg@10: 0.811748
# [390]	valid_0's ndcg@10: 0.811721
# [391]	valid_0's ndcg@10: 0.811754
# [392]	valid_0's ndcg@10: 0.811748
# [393]	valid_0's ndcg@10: 0.811748
# [394]	valid_0's ndcg@10: 0.811754
# [395]	valid_0's ndcg@10: 0.811611
# [396]	valid_0's ndcg@10: 0.811611
# [397]	valid_0's ndcg@10: 0.811222
# [398]	valid_0's ndcg@10: 0.811222
# [399]	valid_0's ndcg@10: 0.811584
# [400]	valid_0's ndcg@10: 0.811584
# [401]	valid_0's ndcg@10: 0.811584
# [402]	valid_0's ndcg@10: 0.810744
# [403]	valid_0's ndcg@10: 0.810789
# [404]	valid_0's ndcg@10: 0.810794
# [405]	valid_0's ndcg@10: 0.810601
# [406]	valid_0's ndcg@10: 0.810591
# [407]	valid_0's ndcg@10: 0.810591
# [408]	valid_0's ndcg@10: 0.810591
# [409]	valid_0's ndcg@10: 0.810629
# [410]	valid_0's ndcg@10: 0.810625
# [411]	valid_0's ndcg@10: 0.810638
# [412]	valid_0's ndcg@10: 0.810638
# [413]	valid_0's ndcg@10: 0.810625
# [414]	valid_0's ndcg@10: 0.810625
# [415]	valid_0's ndcg@10: 0.810625
# [416]	valid_0's ndcg@10: 0.810625
# [417]	valid_0's ndcg@10: 0.810953
# [418]	valid_0's ndcg@10: 0.810953
# [419]	valid_0's ndcg@10: 0.812015
# [420]	valid_0's ndcg@10: 0.812015
# [421]	valid_0's ndcg@10: 0.812015
# [422]	valid_0's ndcg@10: 0.812433
# [423]	valid_0's ndcg@10: 0.812433
# [424]	valid_0's ndcg@10: 0.812163
# [425]	valid_0's ndcg@10: 0.812135
# [426]	valid_0's ndcg@10: 0.811854
# [427]	valid_0's ndcg@10: 0.811831
# [428]	valid_0's ndcg@10: 0.812186
# [429]	valid_0's ndcg@10: 0.812419
# [430]	valid_0's ndcg@10: 0.811521
# [431]	valid_0's ndcg@10: 0.811868
# [432]	valid_0's ndcg@10: 0.811837
# [433]	valid_0's ndcg@10: 0.811534
# [434]	valid_0's ndcg@10: 0.811165
# [435]	valid_0's ndcg@10: 0.810756
# [436]	valid_0's ndcg@10: 0.810836
# [437]	valid_0's ndcg@10: 0.810788
# [438]	valid_0's ndcg@10: 0.810643
# [439]	valid_0's ndcg@10: 0.810654
# [440]	valid_0's ndcg@10: 0.810549
# [441]	valid_0's ndcg@10: 0.810542
# [442]	valid_0's ndcg@10: 0.810534
# [443]	valid_0's ndcg@10: 0.810414
# [444]	valid_0's ndcg@10: 0.810528
# [445]	valid_0's ndcg@10: 0.810536
# [446]	valid_0's ndcg@10: 0.811007
# [447]	valid_0's ndcg@10: 0.810859
# [448]	valid_0's ndcg@10: 0.811421
# [449]	valid_0's ndcg@10: 0.811462
# [450]	valid_0's ndcg@10: 0.81105
# [451]	valid_0's ndcg@10: 0.81136
# [452]	valid_0's ndcg@10: 0.81136
# [453]	valid_0's ndcg@10: 0.811573
# [454]	valid_0's ndcg@10: 0.812043
# [455]	valid_0's ndcg@10: 0.811925
# [456]	valid_0's ndcg@10: 0.81222
# [457]	valid_0's ndcg@10: 0.811756
# [458]	valid_0's ndcg@10: 0.811744
# [459]	valid_0's ndcg@10: 0.811716
# [460]	valid_0's ndcg@10: 0.81202
# [461]	valid_0's ndcg@10: 0.812235
# [462]	valid_0's ndcg@10: 0.812154
# [463]	valid_0's ndcg@10: 0.81198
# [464]	valid_0's ndcg@10: 0.812169
# [465]	valid_0's ndcg@10: 0.81263
# [466]	valid_0's ndcg@10: 0.812753
# [467]	valid_0's ndcg@10: 0.81286
# [468]	valid_0's ndcg@10: 0.812983
# [469]	valid_0's ndcg@10: 0.812748
# [470]	valid_0's ndcg@10: 0.812056
# [471]	valid_0's ndcg@10: 0.812001
# [472]	valid_0's ndcg@10: 0.811678
# [473]	valid_0's ndcg@10: 0.812099
# [474]	valid_0's ndcg@10: 0.81191
# [475]	valid_0's ndcg@10: 0.811857
# [476]	valid_0's ndcg@10: 0.811829
# [477]	valid_0's ndcg@10: 0.812231
# [478]	valid_0's ndcg@10: 0.81219
# [479]	valid_0's ndcg@10: 0.812147
# [480]	valid_0's ndcg@10: 0.812157
# [481]	valid_0's ndcg@10: 0.812332
# [482]	valid_0's ndcg@10: 0.812028
# [483]	valid_0's ndcg@10: 0.812016
# [484]	valid_0's ndcg@10: 0.812161
# [485]	valid_0's ndcg@10: 0.81222
# [486]	valid_0's ndcg@10: 0.812211
# [487]	valid_0's ndcg@10: 0.812152
# [488]	valid_0's ndcg@10: 0.812037
# [489]	valid_0's ndcg@10: 0.811742
# [490]	valid_0's ndcg@10: 0.811562
# [491]	valid_0's ndcg@10: 0.811575
# [492]	valid_0's ndcg@10: 0.811839
# [493]	valid_0's ndcg@10: 0.811466
# [494]	valid_0's ndcg@10: 0.811954
# [495]	valid_0's ndcg@10: 0.811876
# [496]	valid_0's ndcg@10: 0.811733
# [497]	valid_0's ndcg@10: 0.811752
# [498]	valid_0's ndcg@10: 0.811285
# [499]	valid_0's ndcg@10: 0.811326
# [500]	valid_0's ndcg@10: 0.811326

# %% [markdown]
# **Similarly, we choose models basd on cross validation. Here is our experimental results for references. Finally, we ingore model5 becase it brings in negative effects.**
# -------------
#
# | Leaves    | Models |   NDCG@10 |
# | -------- | ------- | ------- |
# | 10  | [0]    | 0.7790606982681543    |
# | 10 | [1]     | 0.7791298174754135    |
# | 10  | [5]    | 0.781309490583906    |
# | 10    | [0,1]    | 0.7884139940363432    |
# | 10    | [0,1,2]    | 0.7883411766547597   |
# | 10    | [0,1,2,3]    | 0.7925544769079671  |
# | 10    | [0,1,3]    | 0.792395820505957  |
# | 10    | [0,1,3,4]    | 0.7921549115058365  |
# | 10    | [0,1,2,3,4]    | 0.792328979445144  |
# | 10    | [0,1,3,5]    |  0.7955011289453335 |
# | 10    | [0,1,2,3,5]    | 0.7957985512498594  |
# | 12    | [0,1,2,3,5] | **0.7959779139881844** |
# | 20    | [0,1,2,3,5] | **0.7964698912399729** |
# | 30    | [0,1,2,3,5] | **0.7966145678395755** |
# | 10    | [0,1,2,3,4,5]    | 0.7956787267202614  |
